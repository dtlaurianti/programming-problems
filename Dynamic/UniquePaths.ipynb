# %% [markdown]
# 62. Unique Paths
# Medium
# 15.6K
# 415
# Companies
#
# There is a robot on an m x n grid. The robot is initially located at the top-left corner (i.e., grid[0][0]). The robot tries to move to the bottom-right corner (i.e., grid[m - 1][n - 1]). The robot can only move either down or right at any point in time.
#
# Given the two integers m and n, return the number of possible unique paths that the robot can take to reach the bottom-right corner.
#
# The test cases are generated so that the answer will be less than or equal to 2 * 109.
#
#
#
# Example 1:
#
# Input: m = 3, n = 7
# Output: 28
#
# Example 2:
#
# Input: m = 3, n = 2
# Output: 3
# Explanation: From the top-left corner, there are a total of 3 ways to reach the bottom-right corner:
# 1. Right -> Down -> Down
# 2. Down -> Down -> Right
# 3. Down -> Right -> Down
#
#
#
# Constraints:
#
#     1 <= m, n <= 100
#
# Accepted
# 1.6M
# Submissions
# 2.5M
# Acceptance Rate
# 63.6%

# %%
class Solution:
    def uniquePaths(self, m: int, n: int) -> int:

        if m==1 and n==1:
            return 1
        
        table = [[0 for c in range(n)] for r in range(m)]
        table[m-1][n-1] = 1

        for bottom_col in range(n-1):
            table[m-1][bottom_col] = 1
        
        for right_row in range(m-1):
            table[right_row][n-1] = 1

        for row in range(m-2,-1, -1):
            for col in range(n-2, -1, -1):
                table[row][col] = table[row+1][col] + table[row][col+1]

        return table[0][0]
        
        # we can more explicitly take advantage of the problem form than this
        '''
        table = [[0 for c in range(n)] for r in range(m)]
        table[m-1][n-1] = 1
        def getNumPaths(r, c):
            if table[r][c] != 0:
                return table[r][c]
            elif r+1 >= m:
                table[r][c] = table[r][c+1]
                return table[r][c]
            elif c+1 >= n:
                table[r][c] = table[r+1][c]
                return table[r][c]
            else:
                table[r][c] = table[r+1][c] + table[r][c+1]
                return table[r][c]

        for i in range(m-1, -1, -1):
            for j in range(n-1, -1, -1):
                getNumPaths(i,j)
        
        return table[0][0]
        '''

# %% [markdown]
# 2-d dynamic programming, sum both options building up the solution from the endpoint.
