# %% [markdown]
# 23. Merge k Sorted Lists
# Hard
# 16.9K
# 614
# Companies
#
# You are given an array of k linked-lists lists, each linked-list is sorted in ascending order.
#
# Merge all the linked-lists into one sorted linked-list and return it.
#
#
#
# Example 1:
#
# Input: lists = [[1,4,5],[1,3,4],[2,6]]
# Output: [1,1,2,3,4,4,5,6]
# Explanation: The linked-lists are:
# [
#   1->4->5,
#   1->3->4,
#   2->6
# ]
# merging them into one sorted list:
# 1->1->2->3->4->4->5->6
#
# Example 2:
#
# Input: lists = []
# Output: []
#
# Example 3:
#
# Input: lists = [[]]
# Output: []
#
#
#
# Constraints:
#
#     k == lists.length
#     0 <= k <= 104
#     0 <= lists[i].length <= 500
#     -104 <= lists[i][j] <= 104
#     lists[i] is sorted in ascending order.
#     The sum of lists[i].length will not exceed 104.
#
# Accepted
# 1.6M
# Submissions
# 3.2M
# Acceptance Rate
# 49.9%

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def mergeKLists(self, lists):
        """
        :type lists: List[ListNode]
        :rtype: ListNode
        """
        if lists == None or len(lists) == 0:
            return None
        elif len(lists) == 1:
            return lists[0]
        elif len(lists) == 2:
            return self.merge(lists[0], lists[1])
        mid = len(lists) // 2
        return self.merge(self.mergeKLists(lists[0:mid]), self.mergeKLists(lists[mid:len(lists)]))

    def merge(self, listA, listB):
        if listA is None:
            return listB
        if listB is None:
            return listA
        if listA.val <= listB.val:
            curr = listA
            while curr.next is not None and listB is not None:
                if curr.next.val <= listB.val:
                    curr = curr.next
                else:
                    temp = curr.next
                    curr.next = listB
                    listB = listB.next
                    curr = curr.next
                    curr.next = temp
            if listB is not None:
                curr.next = listB
            return listA
        else:
            curr = listB
            while curr.next is not None and listA is not None:
                if curr.next.val <= listA.val:
                    curr = curr.next
                else:
                    temp = curr.next
                    curr.next = listA
                    listA = listA.next
                    curr = curr.next
                    curr.next = temp
            if listA is not None:
                curr.next = listA
            return listB
        

'''
BRUTE FORCE APPROACH
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def mergeKLists(self, lists):
        """
        :type lists: List[ListNode]
        :rtype: ListNode
        """
        if len(lists) == 0:
            return None
        if all(lN is None for lN in lists):
            return None
        min = sys.maxsize
        minList = None
        for i in range(len(lists)):
                if lists[i] is not None and lists[i].val < min:
                    min = lists[i].val
                    minList = i
        mergeHead = lists[minList]
        mergeTail = lists[minList]
        lists[minList] = lists[minList].next
        while not all(lN is None for lN in lists):
            min = sys.maxsize
            for i in range(len(lists)):
                if lists[i] is not None and lists[i].val < min:
                    min = lists[i].val
                    minList = i
            mergeTail.next = lists[minList]
            mergeTail = lists[minList]
            lists[minList] = lists[minList].next
        return mergeHead
'''
# Out:
# '\nBRUTE FORCE APPROACH\n# Definition for singly-linked list.\n# class ListNode(object):\n#     def __init__(self, val=0, next=None):\n#         self.val = val\n#         self.next = next\nclass Solution(object):\n    def mergeKLists(self, lists):\n        """\n        :type lists: List[ListNode]\n        :rtype: ListNode\n        """\n        if len(lists) == 0:\n            return None\n        if all(lN is None for lN in lists):\n            return None\n        min = sys.maxsize\n        minList = None\n        for i in range(len(lists)):\n                if lists[i] is not None and lists[i].val < min:\n                    min = lists[i].val\n                    minList = i\n        mergeHead = lists[minList]\n        mergeTail = lists[minList]\n        lists[minList] = lists[minList].next\n        while not all(lN is None for lN in lists):\n            min = sys.maxsize\n            for i in range(len(lists)):\n                if lists[i] is not None and lists[i].val < min:\n   
# ...

# %% [markdown]
# Use a heap merge algorithm to recursively merge the linkedlists two at a time.
