# %% [markdown]
# 424. Longest Repeating Character Replacement
# Medium
# 9.3K
# 394
# Companies
#
# You are given a string s and an integer k. You can choose any character of the string and change it to any other uppercase English character. You can perform this operation at most k times.
#
# Return the length of the longest substring containing the same letter you can get after performing the above operations.
#
#
#
# Example 1:
#
# Input: s = "ABAB", k = 2
# Output: 4
# Explanation: Replace the two 'A's with two 'B's or vice versa.
#
# Example 2:
#
# Input: s = "AABABBA", k = 1
# Output: 4
# Explanation: Replace the one 'A' in the middle with 'B' and form "AABBBBA".
# The substring "BBBB" has the longest repeating letters, which is 4.
# There may exists other ways to achive this answer too.
#
#
#
# Constraints:
#
#     1 <= s.length <= 105
#     s consists of only uppercase English letters.
#     0 <= k <= s.length
#
# Accepted
# 535.5K
# Submissions
# 1M
# Acceptance Rate
# 52.6%

# %%
from collections import Counter
class Solution:
    def characterReplacement(self, s: str, k: int) -> int:
        # the index of the start of the substring window
        window = 0
        # the maximum frequency of any character in the window
        maxcount = 0
        # the frequency of all characters in the window
        freq = Counter()
        # iterate over the string
        for index, ch in enumerate(s):
            # increment the frequency count for the current character
            freq[ch] += 1
            # if the current character is the most frequent, update the max
            maxcount = max(maxcount, freq[ch])
            # if the window is wider than the most frequent character plus k swaps
            # shrink the window and remove the first character added to it
            if maxcount + k <= index - window:
                freq[s[window]] -= 1
                window += 1
        
        # the window is now as wide as the longest satsifactory substring
        return len(s) - window

'''
Too slow, need to use a frequency counting method
class Solution:
    def characterReplacement(self, s: str, k: int) -> int:
        l = len(s)
        longest = k

        for start in range(0,len(s)-k):
            swaps = k
            curr = start + 1

            while curr < l and swaps >= 0:
                if s[curr] != s[start]:
                    swaps -= 1
                curr += 1
            
            longest = max(longest, curr-start+swaps)

            if longest >= l:
                longest = l
                break

        return longest
'''

# %% [markdown]
# Use a sliding window that expands as long as we can turn the window into a satsifacory substring, move it forward when we cannot.
